# %%
## This is a python port of Dr. Matt Maschmann's Matlab CNT growth simulation code. This script simulates an iterative CNT
#  growth process by introducing new material at each time step and then solving for the finite element interactions (stress
#  and strain of the finite elements are modeled as a beam) between steps. NOTE: THE GLOBAL VARIABLES DEFINED ON LINES 5 AND
#  6 IN MATLAB ARE DEFINED AS LOCAL ONES HERE FOR SIMPLICITY (classes and mods to be introduced to the python script later)
from pathlib import Path
import math
import numpy as np
import time
import scipy
from scipy.sparse import *
from scipy.sparse import coo_matrix, linalg as sla
from scipy import *
import random as rand
from scipy.sparse.linalg import spsolve, bicg
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import imageio
import os
from sklearn.neighbors import NearestNeighbors

# %%
#initialize these variables first - the sizes of initialized arrays are functions of these 3 parameters
span=25e-6 #modeling regime (meters) - want 10 CNT per micron - this way they interact during growth
numberBeams=250 #adjust to fit troubleshooting needs, original is 250 - need to make sure they interact during growth
steps=200  #number of growth steps

##List of all arrays that grow in matlab
meanvdw=np.zeros((steps,1));meanvdwsmall=np.zeros((steps,1))
medianvdw=np.zeros((steps,1));maxvdw=np.zeros((steps,1))
minvdw=np.zeros((steps,1));origin=np.zeros(numberBeams)
ang=np.zeros(numberBeams);rate=np.zeros(numberBeams)
ro=np.zeros(steps*numberBeams);ri=np.zeros(numberBeams)
nodeCoordinates=np.zeros(((steps+2)*numberBeams,2))
nucleationSite=np.zeros((numberBeams,2))
growthNode=np.zeros((numberBeams,2))
elementNodes=np.zeros(((steps+2)*numberBeams,2),dtype=int)
L=np.zeros((steps+1)*numberBeams);A=np.zeros((steps+1)*numberBeams)
E=np.zeros((steps+1)*numberBeams);I=np.zeros((steps+1)*numberBeams)
C=np.zeros(steps*numberBeams);S=np.zeros(steps*numberBeams)

E_0=np.ones(numberBeams)*1E12;rout=5E-9; rin=0.7*rout # Modulus ; outer radius; inner radius
g_mod=1e11; a_cc=math.pi*(rout**2-rin**2) #Shear modulus; cross-sectional area
I_def=np.pi/4*(rout**4-rin**4)
gap=50e-9; gap2=gap**2; A_0=np.ones(numberBeams)*a_cc #note, this 
            #does not support unique CNT radii

# %%
#windows
#fname=Path("/Users/Gordo/Desktop/CNT/Images/Junk/") # NOTE: Currently, files are saved to this directory
#ubuntu
fname=os.path.join(os.path.expanduser('~'),'Documents', 'results', 'CNT', 'Images')

#title='Test' #These lines set up image names
#name=title
#title2=name+'_Float3'

title = 'Test'  # Base title
name = title

# Example number to format as four-digit
float_number = 3

# Format the number as four digits with leading zeros and append to 'Float'
title2 = f"{name}_Float{float_number:04d}"


avgRate=60e-9 # Average growth per time step (meters)
rate_stdev=4 #growth rate standard deviation
ang_stdev=3 #growth angle standard deviation


## INPUT SETTINGS - should we use boolean data types in python?
computeVDW=0 # compute vdW forces? 0=  no
ContinuousPlot=0 # 0=plotting off.  1=plotting on
PeriodicBoundary=1 # 0=off, 1=on
beamType=0 # 0=Euler Beam ; 1=Timoshenko Beam
totalCompress=0 # if using compression
compressiveLoad=0 # if using compression
element=numberBeams # sets the number of elements = number of CNTs
nodeCount=2*numberBeams # initial number of evaluation nodes

# %%
## Define nucleate_Uniform function
def nucleate_Uniform(numberBeams,span,avgRate,rout,rin,rate_stdev,ang_stdev,E):
    
    for o in range(numberBeams):
        origin[o]=span/(numberBeams)*(o+1/2);##+span/(numberBeams-1)*rand()
    
   
    
    rand.seed() #Re-seed random number generator
    
    ## Here we nucleate the rates of the beams

    for ii in range(numberBeams): ## 1/3 of the beams will grow more slowly
        mu_ang=math.pi/2
        Sigma_ang=np.atleast_2d((ang_stdev*math.pi/180)**2)
        R_ang=np.linalg.cholesky(Sigma_ang)
        ang[ii]=mu_ang+np.random.normal()*R_ang

        rand.seed()
        mu_rate=avgRate
        Sigma_rate=np.atleast_2d((rate_stdev/100*avgRate)**2)
        R_rate=np.linalg.cholesky(Sigma_rate)
        rate[ii]=mu_rate+np.random.normal()*R_rate
    
        ro[ii]=rout
        ri[ii]=rin
        I[ii]= (math.pi/4)*(rout**4-rin**4)
        
    E=E #recyle the initial E - an array defining the 

    nodeCount=0
    element=0
    
    for num in range(numberBeams,2*numberBeams): ## Assign bottom coordinates to first generation of CNTs
        nodeCount=nodeCount+1
        nodeCoordinates[num,0]=origin[num-numberBeams]  ##defines the x-location of nucleation.
        nodeCoordinates[num,1]=0
    
        nucleationSite[num-numberBeams,0]=nodeCoordinates[num,0] ##xx(num)
        nucleationSite[num-numberBeams,1]=nodeCoordinates[num,1] ##yy(num)
    
    for num in range(numberBeams): ##Setting position of CNT free ends (top nodes)
        nodeCount=nodeCount+1
        nodeCoordinates[num,0]=nodeCoordinates[num+numberBeams,0]+math.cos(ang[num])*rate[num]
        nodeCoordinates[num,1]=nodeCoordinates[num+numberBeams,1]+math.sin(ang[num])*rate[num]
       
        growthNode[num,0]=nodeCoordinates[num,0]
        growthNode[num,1]=nodeCoordinates[num,1]
        
        elementNodes[element,0]=element
        elementNodes[element,1]=nodeCount-1
        element=element+1
        

    return [elementNodes,ang,rate,nodeCoordinates,nodeCount,element,nucleationSite,growthNode,ro,ri,E,I]

# %%
def StiffnessPartial(E,A,I,L,C,S,G,element,elementNodes,GDof,beamType,totalDOFs):

    ## In the 2D stiffness matrix, there are 6 unique entries. They are
    #  labeled as w1... w6 here.

    alpha=1 # this has never been activated...
    if beamType==0:
        epsilon=0
    else:
        epsilon=(12*alpha/g_mod)*np.multiply(E,np.divide(I,A,out=np.zeros_like(A),where=A!=0))

        
    #Ni and Nj are indices that take element nodes and assigns each node an
    #appropriate location within the stiffness matrix, K

    Ni=np.atleast_2d(3*(elementNodes[:A.shape[0],0])-1)
    Nj=np.atleast_2d(3*(elementNodes[:A.shape[0],1])-1)
    
    #Each element will have 36 entries into a stiffness matrix. ii_local and
    #jj_local are the indices associated with each of the 36 entries. This step
    #was taken for vectorization
    ii_local=np.concatenate((Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3),axis=0)
    jj_local=np.concatenate((Ni+1,Ni+1,Ni+1,Ni+1,Ni+1,Ni+1,Ni+2,Ni+2,Ni+2,Ni+2,Ni+2,Ni+2,Ni+3,Ni+3,Ni+3,Ni+3,Ni+3,Ni+3,Nj+1,Nj+1,Nj+1,Nj+1,Nj+1,Nj+1,Nj+2,Nj+2,Nj+2,Nj+2,Nj+2,Nj+2,Nj+3,Nj+3,Nj+3,Nj+3,Nj+3,Nj+3),axis=0)
    
    #multiply arrays first
    E_L=np.divide(E,L,out=np.zeros_like(L),where=L!=0)
    A_C_C=np.multiply(A,np.square(C))
    A_S_S=np.multiply(A,np.square(S))
    I_S_S_12=12*np.multiply(I,np.square(S))
    I_C_C_12=12*np.multiply(I,np.square(C))
    L_L=np.square(L)
    eps_1=np.ones(L.shape)+epsilon
    L_L_eps1=np.multiply(L_L,eps_1)
    S_C=np.multiply(S,C)
    I_S=np.multiply(I,S)
    I_C=np.multiply(I,C)
    I_L_L_eps1=np.divide(I,L_L_eps1,out=np.zeros_like(L_L_eps1),where=L_L_eps1!=0)
    L_eps1=np.multiply(L,eps_1)
    # The six unique stiffness matrix entries are computed below
    w1=np.multiply(E_L,(A_C_C + np.divide(I_S_S_12,L_L_eps1,out=np.zeros_like(L_L_eps1),where=L_L_eps1!=0)))
    w2=np.multiply(E_L,(A_S_S + np.divide(I_C_C_12,L_L_eps1,out=np.zeros_like(L_L_eps1),where=L_L_eps1!=0)))
    w3=np.multiply(E_L,(np.multiply((A-12*I_L_L_eps1),S_C)))
    w4=np.multiply(E_L,(6.*np.divide(I_S,L_eps1,out=np.zeros_like(L_L_eps1),where=L_L_eps1!=0)))
    w5=np.multiply(E_L,(6.*np.divide(I_C,L_eps1,out=np.zeros_like(L_L_eps1),where=L_L_eps1!=0)))
    
    ## Creates a vectorized set of K matrix entries, Kg. Each element will have 
    # 36 entries. The code below create a vector of 36 entries for each element
    # in the system
    Kg=np.zeros((E.shape[0],36))
    Kg[0:E.shape[0],0]=w1
    Kg[0:E.shape[0],1]=w3
    Kg[0:E.shape[0],2]=-w4
    Kg[0:E.shape[0],3]=-w1
    Kg[0:E.shape[0],4]=-w3
    Kg[0:E.shape[0],5]=-w4
    Kg[0:E.shape[0],6]=w3
    Kg[0:E.shape[0],7]=w2
    Kg[0:E.shape[0],8]=w5
    Kg[0:E.shape[0],9]=-w3
    Kg[0:E.shape[0],10]=-w2
    Kg[0:E.shape[0],11]=w5
    Kg[0:E.shape[0],12]=-w4
    Kg[0:E.shape[0],13]=w5
    Kg[0:E.shape[0],14]=4*np.multiply(I,E_L)
    Kg[0:E.shape[0],15]=w4
    Kg[0:E.shape[0],16]=-w5
    Kg[0:E.shape[0],17]=2*np.multiply(I,E_L)
    Kg[0:E.shape[0],18]=-w1
    Kg[0:E.shape[0],19]=-w3
    Kg[0:E.shape[0],20]=w4
    Kg[0:E.shape[0],21]=w1
    Kg[0:E.shape[0],22]=w3
    Kg[0:E.shape[0],23]=w4
    Kg[0:E.shape[0],24]=-w3
    Kg[0:E.shape[0],25]=-w2
    Kg[0:E.shape[0],26]=-w5
    Kg[0:E.shape[0],27]=w3
    Kg[0:E.shape[0],28]=w2
    Kg[0:E.shape[0],29]=-w5
    Kg[0:E.shape[0],30]=-w4
    Kg[0:E.shape[0],31]=w5
    Kg[0:E.shape[0],32]=2*np.multiply(I,E_L)
    Kg[0:E.shape[0],33]=w4
    Kg[0:E.shape[0],34]=-w5
    Kg[0:E.shape[0],35]=4*np.multiply(I,E_L)
    Kg=np.transpose(Kg)
    
    # Creates a sparse matrix based upon the indices and values created above
    Kg_flat=Kg.flatten()
    ii_flat=ii_local.flatten()
    jj_flat=jj_local.flatten()
    K=coo_matrix((Kg_flat,(ii_flat,jj_flat)),shape=(totalDOFs,totalDOFs)).tocsr()
    # the dimensions are: [row, column, value, sparse matrix n dim, sparse matrix m dim], COO format
    return K

# %%
## Define ConnectionStiffness_Partial
def ConnectionStiffness_Partial(E,rout,CC,SS,sizeClose,closeNodes,GDof,beamType,totalDOFs):
#erased unused quantities E, Ac, Ic, LL, G, EI

    ## In the 2D stiffness matrix, there are 6 unique entries. They are
    #  labeled as w1... w6 here.
    vdwk=np.zeros(CC.shape[0])

    alpha=1 # this has never been activated...
    if beamType==0:
        epsilon=0
    else:
        epsilon=0
        print('this has unintended effect')

    #vdwk=E
    if np.any(ro==5e-09):
        vdwk=273*np.ones(vdwk.shape) #Spring stiffness of bar element between CNTs
    elif np.any(ro==12.5e-09):
        vdwk=430*np.ones(vdwk.shape)
    else:
        print('check CNT Radii')

    #Ni and Nj are indices that take element nodes and assigns each node an
    #appropriate location within the stiffness matrix, K

    Ni=np.atleast_2d(3*(closeNodes[:,0])-1)
    Nj=np.atleast_2d(3*(closeNodes[:,1])-1)        
        
    #Each element will have 36 entries into a stiffness matrix. ii_local and
    #jj_local are the indices associated with each of the 36 entries. This step
    #was taken for vectorization
    ii_local=np.concatenate((Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3,Ni+1,Ni+2,Ni+3,Nj+1,Nj+2,Nj+3),axis=0)
    jj_local=np.concatenate((Ni+1,Ni+1,Ni+1,Ni+1,Ni+1,Ni+1,Ni+2,Ni+2,Ni+2,Ni+2,Ni+2,Ni+2,Ni+3,Ni+3,Ni+3,Ni+3,Ni+3,Ni+3,Nj+1,Nj+1,Nj+1,Nj+1,Nj+1,Nj+1,Nj+2,Nj+2,Nj+2,Nj+2,Nj+2,Nj+2,Nj+3,Nj+3,Nj+3,Nj+3,Nj+3,Nj+3),axis=0)

    w1=np.multiply(vdwk,np.square(CC))
    w2=np.multiply(vdwk,np.multiply(SS,CC))    
    w3=np.multiply(vdwk,np.square(SS))

    ## Creates a vectorized set of K matrix entries, Kg. Each element will have 
    # 36 entries. The code below create a vector of 36 entries for each element
    # in the system
    Kg=np.zeros((sizeClose,36))
    Kg[0:sizeClose,0]=w1
    Kg[0:sizeClose,1]=w2
    Kg[0:sizeClose,2]=0
    
    Kg[0:sizeClose,3]=-w1
    Kg[0:sizeClose,4]=-w2
    Kg[0:sizeClose,5]=0
    
    Kg[0:sizeClose,6]=w2
    Kg[0:sizeClose,7]=w3
    Kg[0:sizeClose,8]=0
    
    Kg[0:sizeClose,9]=-w2
    Kg[0:sizeClose,10]=-w3
    Kg[0:sizeClose,11]=0
    
    Kg[0:sizeClose,12]=0
    Kg[0:sizeClose,13]=0
    Kg[0:sizeClose,14]=0
    Kg[0:sizeClose,15]=0
    Kg[0:sizeClose,16]=0
    Kg[0:sizeClose,17]=0
    
    Kg[0:sizeClose,18]=-w1
    Kg[0:sizeClose,19]=-w2
    Kg[0:sizeClose,20]=0
    
    Kg[0:sizeClose,21]=w1
    Kg[0:sizeClose,22]=w2
    Kg[0:sizeClose,23]=0
    
    Kg[0:sizeClose,24]=-w2
    Kg[0:sizeClose,25]=-w3
    Kg[0:sizeClose,26]=0
    
    Kg[0:sizeClose,27]=w2
    Kg[0:sizeClose,28]=w3
    Kg[0:sizeClose,29]=0
    
    Kg[0:sizeClose,30]=0
    Kg[0:sizeClose,31]=0
    Kg[0:sizeClose,32]=0
    Kg[0:sizeClose,33]=0
    Kg[0:sizeClose,34]=0
    Kg[0:sizeClose,35]=0
    
    Kg=np.transpose(Kg)
    
    # Creates a sparse matrix based upon the indices and values created above
    Kg_flat=Kg.flatten()
    ii_flat=ii_local.flatten()
    jj_flat=jj_local.flatten()
    ii_flat[ii_flat<0]=0
    jj_flat[jj_flat<0]=0
    AA=coo_matrix((Kg_flat,(ii_flat,jj_flat)),shape=(totalDOFs,totalDOFs)).tocsr()
    
    return [AA,vdwk]

# %%
import os
import matplotlib.pyplot as plt

def CNTPlotFast(fname, nodeCoordinates, t, title):
    # Create directory if it doesn't exist
    directory = os.path.dirname(fname)
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    fig = plt.figure(figsize=(5.0, 5.0), dpi=800)
    plt.title(title)
    plt.xlabel('Substrate Position (µm)')
    plt.ylabel('Forest Height (µm)')
    # Assuming 'span' and 'nodeCount' are defined elsewhere or need to be extracted from 'nodeCoordinates'
    plt.xlim((0, max(nodeCoordinates[:, 0]) * 1e6))
    plt.ylim((0, max(nodeCoordinates[:, 1]) * 1e6))
    plt.plot(nodeCoordinates[:, 0] * 1e6, nodeCoordinates[:, 1] * 1e6, marker='.', ms=1, lw=0, color='black')
    
    # Format the filename with t as a four-digit number
    filename = f"{fname}_{t:04d}.png"
    
    plt.savefig(filename, dpi=800)
    plt.close(fig)  # Close the figure to free memory

# %%
### define the closenodes logic
def FindCloseNodes_Range2a(nodeCoordinates,nodeCount,numberBeams,ro,closeNodes):
    gap=2*ro+20e-9;
    X=nodeCoordinates
    nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(X)
    distances, indices = nbrs.kneighbors(X)
    closeNodes=indices[np.argwhere((distances>0) & (distances<gap))[:,0]]
    if closeNodes.shape[0]==0:
        closeNodes=np.atleast_2d(np.array([0,0]))
    
    return closeNodes

# %%
########################################################################
##/ nucleating CNTs with distributed properties according to inputs####/
########################################################################

[elementNodes,ang,rate,nodeCoordinates,nodeCount,element,nucleationSite,growthNode,ro,ri,E,I]=nucleate_Uniform(numberBeams,span,avgRate,rout,rin,rate_stdev,ang_stdev,E)

ss=steps+2
angle=np.tile((np.transpose(ang)),ss) #steps=1350  #number of time stepsangle of each node

E=np.transpose(E) #reshape modulus

sizeClose=0 #number of closeNodes. See below
closeNodes=np.atleast_2d(np.zeros((1,2),dtype=int)) #closeNodes are paired lists of nodes (node numbers) in contact
closeNodesOLD=np.atleast_2d(np.zeros((1,2),dtype=int))
closeNodesNew=np.atleast_2d(np.zeros((1,2),dtype=int))
firstNodeCompare=0
removedNodes1=[0,0];removedNodes2=[0,0]

###########################################################################
FF=(steps+1)*numberBeams*3 ### I dont think this is used. It was intended
Uaccumulated=np.zeros((FF,1)) ### to track the total translation of each node
Ucurrent=np.zeros((FF,1))
###########################################################################

totalNodes=numberBeams*(steps+2)  # total number of nodes at the end of simulation
totalDOFs=numberBeams*(steps+2)*3 # DOF = degrees of freedom at the end of simulation

########################################################################
        ####/ initialize t=0 element material variables  ####/
########################################################################

e_0=np.arange(0,numberBeams) #index of initial beam
L[e_0]=rate #should we track rate for each element at each time step?
A[e_0]=A_0
E[e_0]=E_0
I[e_0]=np.transpose(I[e_0])
ro[e_0]=np.transpose(ro[e_0])
# Out:
# /var/folders/xs/5688kgc54c12jm1b6pjmrldr0000gn/T/ipykernel_99129/1712213179.py:17: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ang[ii]=mu_ang+np.random.normal()*R_ang
# /var/folders/xs/5688kgc54c12jm1b6pjmrldr0000gn/T/ipykernel_99129/1712213179.py:23: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   rate[ii]=mu_rate+np.random.normal()*R_rate

# %%
##############################################################################
#####################   BEGIN GROWTH STEPS  ##################################
##############################################################################
timer1=time.time()
for t in range(steps):
    closeNodes=closeNodesOLD; ## initializes nodes in contact to null 
    timer2=time.time()
    dx=np.zeros(element)
    dy=np.zeros(element)
    if t>0: #assigning properties to newly-grown elements
        e=((element-numberBeams)*np.ones(np.arange(0,numberBeams).size)+np.arange(0,numberBeams)).astype(int)
        e_e=np.arange(0,e.shape[0])
        L[e]=rate #should we track rate for each element at each time step?
        A[e]=A_0
        E[e]=E_0
        I[e]=np.transpose(I[e_e])
        ro[e]=np.transpose(ro[e_e])
        
    GDof=3*(nodeCount); # Global Degrees of Freedom

    closeNodes=FindCloseNodes_Range2a(nodeCoordinates[:nodeCount,:],nodeCount,numberBeams,ro[0],closeNodes)
    
    U=np.zeros((GDof,1)); force=np.zeros((GDof,1)) ##initializing variables
    i=0; ii=np.zeros((36,1)); iii=np.zeros((36,1)); j=0; jj=np.zeros((36,1)); jjj=np.zeros((36,1))
    vdwEquilForce=np.zeros((GDof, 1))
    
    dx[:element]=(nodeCoordinates[elementNodes[:nodeCount,1],0]-nodeCoordinates[elementNodes[:nodeCount,0],0])[:element]
    dy[:element]=(nodeCoordinates[elementNodes[:nodeCount,1],1]-nodeCoordinates[elementNodes[:nodeCount,0],1])[:element]
    
    #if PeriodicBoundary>0;         # For periodic boundary
    #conditions, if an element moves 6-1-20 Matt - can add later
    #    crossedl=find(xa>span/2);  # across a boundary, it shows up on the other side of 
    #    xa(crossedl)=xa(crossedl)-span; # the simulation domain 
    #    crossedr=find( xa <(-span/2 ) );
    #    xa(crossedr)=xa(crossedr)+span;
    #end

    Ldef=np.sqrt(np.square(dx)+np.square(dy))
    C=np.divide(dx,Ldef,out=np.zeros_like(Ldef),where=Ldef!=0)
    S=np.divide(dy,Ldef,out=np.zeros_like(Ldef),where=Ldef!=0)  #Computes Cosine and Sine for each element
    K=StiffnessPartial(E[:element],A[:element],I[:element],L[:element],C,S,g_mod,element,elementNodes[0:int(GDof),:],GDof,beamType,totalDOFs)
        
    ##### ATTRACIVE FORCES BY VAN DER WAALS ATTRACTION #############
    ################################################################
    
    vdwk=273 ####Should change this command line
    
    if closeNodes[0,:].all !=[0,0] and closeNodesOLD[0,:].all != [0,0]: #This isn't sufficient because closeNodes can get dropped
                
        closeNodesCombined=np.vstack((closeNodes,closeNodesOLD)) #This ensures that nodes were not accidentally missed by closeNodes call
        closeNodes=np.unique(closeNodesCombined,axis=0) #Updated list of closeNodes for time t
            
        if (closeNodes[0,:]==[0,0]).all(): #this is formatting for below
            closeNodes=np.delete(closeNodes,0,0);
            
        droppedNodesAdded=1
        print('droppedNodesAdded = '+str(droppedNodesAdded))
            
        ######################################################################
    
        # FINDING NEW CLOSENODES AND ESTABLISHING THEIR COORDINATES OF FIRST CONTACT         

        new_pairs=closeNodes #The first time close nodes are present
        vdwInfo=0

        ################ Computes the AA stiffness matrix  ###################
        sizeClose=closeNodes.shape[0]

        xa=nodeCoordinates[closeNodes[:,1],0]-nodeCoordinates[closeNodes[:,0],0]
        ya=nodeCoordinates[closeNodes[:,1],1]-nodeCoordinates[closeNodes[:,0],1]

        LL=np.sqrt(np.square(xa)+np.square(ya)); CC=np.divide(xa,LL); SS=np.divide(ya,LL)
        [AA,vdwk]=ConnectionStiffness_Partial(E,ro,CC,SS,sizeClose,closeNodes,GDof,beamType,totalDOFs)

        ######################################################################
        ######################################################################             

        K=K+AA # Adds vdW force to the global stiffness matrix
        
    ## Setting boundary conditions to solve for displacement #################

    ##########################################################################
    
    pdof=np.arange(numberBeams)
    
    #The lines below are boundary conditions that set the location for the
    #top node of the bottom element. U is displacement.
    U[GDof-3*numberBeams+3*pdof+0]=np.transpose(np.atleast_2d(np.multiply(rate,np.cos(ang))))
    U[GDof-3*numberBeams+3*pdof+1]=np.transpose(np.atleast_2d(np.multiply(rate,np.sin(ang))))
    U[GDof-3*numberBeams+3*pdof+2]=0
    
    alldof=np.arange((GDof-3*numberBeams),GDof) #% alldof is all fixed degrees of freedom
    prescribedDof=np.transpose(alldof) # Re-alinging alldof into a vector

    ##########################################################################
 
    activeDof=np.setdiff1d(np.arange(GDof),prescribedDof) #All free nodes in the system
    minus_K=-K[activeDof[0]:activeDof[-1]+1,prescribedDof[0]:prescribedDof[-1]+1]
    bc_U=csr_matrix(U[prescribedDof])
    
    timer3=time.time()    
    K_U=np.multiply(minus_K,bc_U)    
    displacements=spsolve(K[activeDof[0]:activeDof[-1]+1,activeDof[0]:activeDof[-1]+1],K_U)   
    print('Elapsed matrix solver time is '+str(time.time()-timer3)+' seconds.')
    
    U[activeDof[0]:activeDof[-1]+1]=np.transpose(np.atleast_2d(displacements)) #Defines the displacement of the free nodes
    i_i=np.arange(nodeCount)  #-numberBeams; ##Translates all nodes
    nodeCoordinates[i_i,0]=nodeCoordinates[i_i,0]+U[3*i_i].flatten()
    nodeCoordinates[i_i,1]=nodeCoordinates[i_i,1]+U[3*i_i+1].flatten()
    angle[i_i]=angle[i_i]+U[3*i_i+2].flatten()
    
    #if PeriodicBoundary>0; - add later
    #         crossedl=find(nodeCoordinates(:,1)<0);% moves across left boundary
    #         nodeCoordinates(crossedl,1)=nodeCoordinates(crossedl,1)+span;
    #         crossedr=find(nodeCoordinates(:,1)>span);
    #         nodeCoordinates(crossedr,1)=nodeCoordinates(crossedr,1)-span;
    #end

    currentCount=nodeCount

    ## Dividing the bottom-most elements ##
    for kk in range(currentCount,currentCount+numberBeams):
        nodeCoordinates[kk,0]=nucleationSite[kk-currentCount,0]
        nodeCoordinates[kk,1]=nucleationSite[kk-currentCount,1]
        elementNodes[element,0]=element
        elementNodes[element,1]=nodeCount
        element+=1
        nodeCount+=1

    print('t='+str(t))
    print('Elapsed time is '+str(time.time()-timer2)+' seconds.')


    if (t+1)%2==0: #plots every 2 steps
        print('plot me')
        CNTPlotFast(fname,nodeCoordinates[:nodeCount],t,title) #for python, only send the written nodeCoordinates

time1=time.time()-timer1
print('Total Elapsed time is '+str(time.time()-timer1)+' seconds.')
# Out:
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.0005078315734863281 seconds.
# t=0
# Elapsed time is 0.005331993103027344 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.000782012939453125 seconds.
# t=1
# Elapsed time is 0.005501985549926758 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.0012660026550292969 seconds.
# t=2
# Elapsed time is 0.007097005844116211 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.0018911361694335938 seconds.
# t=3
# Elapsed time is 0.0076482295989990234 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.0025968551635742188 seconds.
# t=4
# Elapsed time is 0.009331941604614258 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.003184795379638672 seconds.
# t=5
# Elapsed time is 0.011134147644042969 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.004034996032714844 seconds.
# t=6
# Elapsed time is 0.012731313705444336 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.004386186599731445 seconds.
# t=7
# Elapsed time is 0.01339101791381836 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.005051851272583008 seconds.
# t=8
# Elapsed time is 0.015227317810058594 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.005698204040527344 seconds.
# t=9
# Elapsed time is 0.017275094985961914 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.006110191345214844 seconds.
# t=10
# Elapsed time is 0.017976999282836914 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.006309032440185547 seconds.
# t=11
# Elapsed time is 0.02089095115661621 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.00688624382019043 seconds.
# t=12
# Elapsed time is 0.020004749298095703 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.007430076599121094 seconds.
# t=13
# Elapsed time is 0.020763874053955078 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.008089065551757812 seconds.
# t=14
# Elapsed time is 0.02149033546447754 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.008607864379882812 seconds.
# t=15
# Elapsed time is 0.022572994232177734 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.009216070175170898 seconds.
# t=16
# Elapsed time is 0.02424025535583496 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.010175943374633789 seconds.
# t=17
# Elapsed time is 0.025712013244628906 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.010956764221191406 seconds.
# t=18
# Elapsed time is 0.027786970138549805 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.011638641357421875 seconds.
# t=19
# Elapsed time is 0.028764009475708008 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.012213945388793945 seconds.
# t=20
# Elapsed time is 0.030230998992919922 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.012874841690063477 seconds.
# t=21
# Elapsed time is 0.03200697898864746 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.014095783233642578 seconds.
# t=22
# Elapsed time is 0.0387880802154541 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.01477193832397461 seconds.
# t=23
# Elapsed time is 0.03522992134094238 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.015745162963867188 seconds.
# t=24
# Elapsed time is 0.037598371505737305 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.015841007232666016 seconds.
# t=25
# Elapsed time is 0.03770303726196289 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.018244028091430664 seconds.
# t=26
# Elapsed time is 0.04362130165100098 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.018826961517333984 seconds.
# t=27
# Elapsed time is 0.043647050857543945 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.020102977752685547 seconds.
# t=28
# Elapsed time is 0.047345876693725586 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.020812034606933594 seconds.
# t=29
# Elapsed time is 0.0453338623046875 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.02619194984436035 seconds.
# t=30
# Elapsed time is 0.05222606658935547 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.023601055145263672 seconds.
# t=31
# Elapsed time is 0.050238847732543945 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.024574756622314453 seconds.
# t=32
# Elapsed time is 0.05462193489074707 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.026188135147094727 seconds.
# t=33
# Elapsed time is 0.054039955139160156 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.02702808380126953 seconds.
# t=34
# Elapsed time is 0.05614805221557617 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.02777409553527832 seconds.
# t=35
# Elapsed time is 0.05656790733337402 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.03062725067138672 seconds.
# t=36
# Elapsed time is 0.0685887336730957 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.03194117546081543 seconds.
# t=37
# Elapsed time is 0.06429100036621094 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.03269314765930176 seconds.
# t=38
# Elapsed time is 0.07041311264038086 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.033531904220581055 seconds.
# t=39
# Elapsed time is 0.06720900535583496 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.035470008850097656 seconds.
# t=40
# Elapsed time is 0.07306718826293945 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.03614163398742676 seconds.
# t=41
# Elapsed time is 0.07209300994873047 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.0408482551574707 seconds.
# t=42
# Elapsed time is 0.07909393310546875 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.03875613212585449 seconds.
# t=43
# Elapsed time is 0.07692432403564453 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.04077506065368652 seconds.
# t=44
# Elapsed time is 0.0800313949584961 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.04169607162475586 seconds.
# t=45
# Elapsed time is 0.08088803291320801 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.04491424560546875 seconds.
# t=46
# Elapsed time is 0.08909916877746582 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.046499013900756836 seconds.
# t=47
# Elapsed time is 0.08980822563171387 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.04873490333557129 seconds.
# t=48
# Elapsed time is 0.09555888175964355 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.04949378967285156 seconds.
# t=49
# Elapsed time is 0.09361505508422852 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.05232596397399902 seconds.
# t=50
# Elapsed time is 0.09899306297302246 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.051570892333984375 seconds.
# t=51
# Elapsed time is 0.09831118583679199 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.05393099784851074 seconds.
# t=52
# Elapsed time is 0.10408902168273926 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.054840087890625 seconds.
# t=53
# Elapsed time is 0.10410618782043457 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.05896902084350586 seconds.
# t=54
# Elapsed time is 0.11166095733642578 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.058474063873291016 seconds.
# t=55
# Elapsed time is 0.1157989501953125 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.061419010162353516 seconds.
# t=56
# Elapsed time is 0.11378788948059082 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.061094045639038086 seconds.
# t=57
# Elapsed time is 0.11530613899230957 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.06940126419067383 seconds.
# t=58
# Elapsed time is 0.12558603286743164 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.06545090675354004 seconds.
# t=59
# Elapsed time is 0.12285423278808594 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.07043695449829102 seconds.
# t=60
# Elapsed time is 0.1258859634399414 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.07178688049316406 seconds.
# t=61
# Elapsed time is 0.12662911415100098 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.07125973701477051 seconds.
# t=62
# Elapsed time is 0.1291031837463379 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.07447195053100586 seconds.
# t=63
# Elapsed time is 0.13488507270812988 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.07447600364685059 seconds.
# t=64
# Elapsed time is 0.13536691665649414 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.07643532752990723 seconds.
# t=65
# Elapsed time is 0.13576912879943848 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.08254098892211914 seconds.
# t=66
# Elapsed time is 0.1451120376586914 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.08072113990783691 seconds.
# t=67
# Elapsed time is 0.14250397682189941 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.08261775970458984 seconds.
# t=68
# Elapsed time is 0.1497199535369873 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.08454298973083496 seconds.
# t=69
# Elapsed time is 0.15079283714294434 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.08683514595031738 seconds.
# t=70
# Elapsed time is 0.15739989280700684 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.08800888061523438 seconds.
# t=71
# Elapsed time is 0.1576828956604004 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.08888483047485352 seconds.
# t=72
# Elapsed time is 0.16022491455078125 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.09398198127746582 seconds.
# t=73
# Elapsed time is 0.1660630702972412 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.09396982192993164 seconds.
# t=74
# Elapsed time is 0.16512107849121094 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.09599804878234863 seconds.
# t=75
# Elapsed time is 0.17116808891296387 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.09966111183166504 seconds.
# t=76
# Elapsed time is 0.17264580726623535 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.10004472732543945 seconds.
# t=77
# Elapsed time is 0.17531275749206543 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.10188698768615723 seconds.
# t=78
# Elapsed time is 0.1794722080230713 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.10294604301452637 seconds.
# t=79
# Elapsed time is 0.1810920238494873 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.10396289825439453 seconds.
# t=80
# Elapsed time is 0.18358588218688965 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.10419011116027832 seconds.
# t=81
# Elapsed time is 0.18318414688110352 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.11412715911865234 seconds.
# t=82
# Elapsed time is 0.19646787643432617 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.10965919494628906 seconds.
# t=83
# Elapsed time is 0.18841791152954102 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.11033201217651367 seconds.
# t=84
# Elapsed time is 0.1936798095703125 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.11270618438720703 seconds.
# t=85
# Elapsed time is 0.19768309593200684 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.11596107482910156 seconds.
# t=86
# Elapsed time is 0.20627307891845703 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.12243008613586426 seconds.
# t=87
# Elapsed time is 0.20730090141296387 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.11790180206298828 seconds.
# t=88
# Elapsed time is 0.20746803283691406 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.12282180786132812 seconds.
# t=89
# Elapsed time is 0.21350789070129395 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.12304306030273438 seconds.
# t=90
# Elapsed time is 0.21817302703857422 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.1255028247833252 seconds.
# t=91
# Elapsed time is 0.2169797420501709 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.13395905494689941 seconds.
# t=92
# Elapsed time is 0.2296760082244873 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.12778592109680176 seconds.
# t=93
# Elapsed time is 0.22212910652160645 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.13748383522033691 seconds.
# t=94
# Elapsed time is 0.2325119972229004 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.1343998908996582 seconds.
# t=95
# Elapsed time is 0.23769402503967285 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.13420534133911133 seconds.
# t=96
# Elapsed time is 0.23569679260253906 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.13750410079956055 seconds.
# t=97
# Elapsed time is 0.24457979202270508 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.14430904388427734 seconds.
# t=98
# Elapsed time is 0.24959635734558105 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.139570951461792 seconds.
# t=99
# Elapsed time is 0.2396552562713623 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.14398813247680664 seconds.
# t=100
# Elapsed time is 0.259127140045166 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.1443798542022705 seconds.
# t=101
# Elapsed time is 0.25759387016296387 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.14643192291259766 seconds.
# t=102
# Elapsed time is 0.2553980350494385 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.14839696884155273 seconds.
# t=103
# Elapsed time is 0.2618367671966553 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.1524028778076172 seconds.
# t=104
# Elapsed time is 0.266387939453125 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.15456295013427734 seconds.
# t=105
# Elapsed time is 0.2642068862915039 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.15661883354187012 seconds.
# t=106
# Elapsed time is 0.2668271064758301 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.1563549041748047 seconds.
# t=107
# Elapsed time is 0.2723219394683838 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.18633484840393066 seconds.
# t=108
# Elapsed time is 0.3197660446166992 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.16736388206481934 seconds.
# t=109
# Elapsed time is 0.2940638065338135 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.18427014350891113 seconds.
# t=110
# Elapsed time is 0.31070590019226074 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2615318298339844 seconds.
# t=111
# Elapsed time is 0.4534912109375 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.16657519340515137 seconds.
# t=112
# Elapsed time is 0.29213476181030273 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.16909408569335938 seconds.
# t=113
# Elapsed time is 0.29366588592529297 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.17725801467895508 seconds.
# t=114
# Elapsed time is 0.3102421760559082 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.17341899871826172 seconds.
# t=115
# Elapsed time is 0.29747819900512695 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.17575311660766602 seconds.
# t=116
# Elapsed time is 0.3045649528503418 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.17769098281860352 seconds.
# t=117
# Elapsed time is 0.302213191986084 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.17984390258789062 seconds.
# t=118
# Elapsed time is 0.3106269836425781 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.18409276008605957 seconds.
# t=119
# Elapsed time is 0.31026291847229004 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.18713998794555664 seconds.
# t=120
# Elapsed time is 0.32427501678466797 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.18645238876342773 seconds.
# t=121
# Elapsed time is 0.30368709564208984 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.19308090209960938 seconds.
# t=122
# Elapsed time is 0.313770055770874 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.19626688957214355 seconds.
# t=123
# Elapsed time is 0.31891369819641113 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.19367003440856934 seconds.
# t=124
# Elapsed time is 0.31699681282043457 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.1961989402770996 seconds.
# t=125
# Elapsed time is 0.31978797912597656 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.19914817810058594 seconds.
# t=126
# Elapsed time is 0.32940077781677246 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.20166015625 seconds.
# t=127
# Elapsed time is 0.3301670551300049 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.20441818237304688 seconds.
# t=128
# Elapsed time is 0.34552717208862305 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2049388885498047 seconds.
# t=129
# Elapsed time is 0.3317139148712158 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2117600440979004 seconds.
# t=130
# Elapsed time is 0.3525822162628174 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.21796393394470215 seconds.
# t=131
# Elapsed time is 0.35156917572021484 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.21644020080566406 seconds.
# t=132
# Elapsed time is 0.3530087471008301 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.22142982482910156 seconds.
# t=133
# Elapsed time is 0.3596489429473877 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.22131800651550293 seconds.
# t=134
# Elapsed time is 0.36010193824768066 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2188558578491211 seconds.
# t=135
# Elapsed time is 0.35518503189086914 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.22240209579467773 seconds.
# t=136
# Elapsed time is 0.36586523056030273 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.22514677047729492 seconds.
# t=137
# Elapsed time is 0.3665778636932373 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2307431697845459 seconds.
# t=138
# Elapsed time is 0.37578701972961426 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.22942376136779785 seconds.
# t=139
# Elapsed time is 0.3703951835632324 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.23203492164611816 seconds.
# t=140
# Elapsed time is 0.37711167335510254 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.23473405838012695 seconds.
# t=141
# Elapsed time is 0.37906980514526367 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.24439597129821777 seconds.
# t=142
# Elapsed time is 0.39924097061157227 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.23607969284057617 seconds.
# t=143
# Elapsed time is 0.38074421882629395 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.24529314041137695 seconds.
# t=144
# Elapsed time is 0.39733004570007324 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.24649286270141602 seconds.
# t=145
# Elapsed time is 0.4005136489868164 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2597670555114746 seconds.
# t=146
# Elapsed time is 0.422961950302124 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.26639485359191895 seconds.
# t=147
# Elapsed time is 0.42251086235046387 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.264984130859375 seconds.
# t=148
# Elapsed time is 0.4257631301879883 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3785529136657715 seconds.
# t=149
# Elapsed time is 0.5549509525299072 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.27061009407043457 seconds.
# t=150
# Elapsed time is 0.439039945602417 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2933528423309326 seconds.
# t=151
# Elapsed time is 0.4639008045196533 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2634851932525635 seconds.
# t=152
# Elapsed time is 0.42836928367614746 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2678859233856201 seconds.
# t=153
# Elapsed time is 0.43306493759155273 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.279094934463501 seconds.
# t=154
# Elapsed time is 0.45621705055236816 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.30533790588378906 seconds.
# t=155
# Elapsed time is 0.4781837463378906 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.27269983291625977 seconds.
# t=156
# Elapsed time is 0.44113683700561523 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.27055811882019043 seconds.
# t=157
# Elapsed time is 0.4408280849456787 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.27788209915161133 seconds.
# t=158
# Elapsed time is 0.4462428092956543 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.27922677993774414 seconds.
# t=159
# Elapsed time is 0.45270586013793945 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.27960705757141113 seconds.
# t=160
# Elapsed time is 0.45329928398132324 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2784900665283203 seconds.
# t=161
# Elapsed time is 0.44845008850097656 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2828853130340576 seconds.
# t=162
# Elapsed time is 0.46001720428466797 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.28665804862976074 seconds.
# t=163
# Elapsed time is 0.4601011276245117 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.29047703742980957 seconds.
# t=164
# Elapsed time is 0.4668612480163574 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.2951629161834717 seconds.
# t=165
# Elapsed time is 0.4684438705444336 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.29740166664123535 seconds.
# t=166
# Elapsed time is 0.4761378765106201 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.29711318016052246 seconds.
# t=167
# Elapsed time is 0.47092294692993164 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3009161949157715 seconds.
# t=168
# Elapsed time is 0.4864158630371094 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.30007386207580566 seconds.
# t=169
# Elapsed time is 0.4853072166442871 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3078579902648926 seconds.
# t=170
# Elapsed time is 0.4975872039794922 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3068230152130127 seconds.
# t=171
# Elapsed time is 0.48830676078796387 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3120310306549072 seconds.
# t=172
# Elapsed time is 0.5062527656555176 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.31165385246276855 seconds.
# t=173
# Elapsed time is 0.4984710216522217 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3420572280883789 seconds.
# t=174
# Elapsed time is 0.5394420623779297 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3192429542541504 seconds.
# t=175
# Elapsed time is 0.5142190456390381 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.31745314598083496 seconds.
# t=176
# Elapsed time is 0.5073459148406982 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.31931281089782715 seconds.
# t=177
# Elapsed time is 0.5114390850067139 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.324326753616333 seconds.
# t=178
# Elapsed time is 0.5225400924682617 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.32872915267944336 seconds.
# t=179
# Elapsed time is 0.5224061012268066 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3249790668487549 seconds.
# t=180
# Elapsed time is 0.528691291809082 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3300337791442871 seconds.
# t=181
# Elapsed time is 0.5236349105834961 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3297569751739502 seconds.
# t=182
# Elapsed time is 0.5321841239929199 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.33570218086242676 seconds.
# t=183
# Elapsed time is 0.5444040298461914 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3503391742706299 seconds.
# t=184
# Elapsed time is 0.556502103805542 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.34052085876464844 seconds.
# t=185
# Elapsed time is 0.5441920757293701 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3428158760070801 seconds.
# t=186
# Elapsed time is 0.5649278163909912 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.34981703758239746 seconds.
# t=187
# Elapsed time is 0.552955150604248 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.36246299743652344 seconds.
# t=188
# Elapsed time is 0.5756781101226807 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.35093021392822266 seconds.
# t=189
# Elapsed time is 0.5635249614715576 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3528258800506592 seconds.
# t=190
# Elapsed time is 0.5700998306274414 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3605680465698242 seconds.
# t=191
# Elapsed time is 0.5764479637145996 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.35996580123901367 seconds.
# t=192
# Elapsed time is 0.5923829078674316 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.36370086669921875 seconds.
# t=193
# Elapsed time is 0.5861201286315918 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3724648952484131 seconds.
# t=194
# Elapsed time is 0.6001987457275391 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3691520690917969 seconds.
# t=195
# Elapsed time is 0.5960841178894043 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.3765251636505127 seconds.
# t=196
# Elapsed time is 0.6084260940551758 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.37787890434265137 seconds.
# t=197
# Elapsed time is 0.6002421379089355 seconds.
# plot me
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.37679505348205566 seconds.
# t=198
# Elapsed time is 0.6145260334014893 seconds.
# droppedNodesAdded = 1
# Elapsed matrix solver time is 0.383195161819458 seconds.
# t=199
# Elapsed time is 0.6117110252380371 seconds.
# plot me
# Total Elapsed time is 155.34041690826416 seconds.
